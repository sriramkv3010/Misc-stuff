# %%
import pandas as pd
pd.read_csv("/content/subs.csv")
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
a=pd.read_csv('/content/subs.csv')
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a=pd.read_csv('/content/subs.csv').squeeze()
a
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
b=pd.read_csv("/content/kohli_ipl.csv",index_col="match_no").squeeze()
b
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
c=pd.read_csv("/content/bollywood.csv",index_col="movie")
c.squeeze()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
c.head() #gives preview of first 5 rows in a table
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar

# %%
c.head(2)
# Out:
#                                    lead
# movie
# Uri: The Surgical Strike  Vicky Kaushal
# Battalion 609               Vicky Ahuja

# %%
c.tail() # give glimpse of last rows
# Out:
#                                     lead
# movie
# Hum Tumhare Hain Sanam    Shah Rukh Khan
# Aankhen (2002 film)     Amitabh Bachchan
# Saathiya (film)             Vivek Oberoi
# Company (film)                Ajay Devgn
# Awara Paagal Deewana        Akshay Kumar

# %%
c.tail(8)
# Out:
#                                         lead
# movie
# Waisa Bhi Hota Hai Part II      Arshad Warsi
# Devdas (2002 Hindi film)      Shah Rukh Khan
# Kaante                      Amitabh Bachchan
# Hum Tumhare Hain Sanam        Shah Rukh Khan
# Aankhen (2002 film)         Amitabh Bachchan
# Saathiya (film)                 Vivek Oberoi
# Company (film)                    Ajay Devgn
# Awara Paagal Deewana            Akshay Kumar

# %%
#sample() gives a row randomly from the series
a.sample()
# Out:
# 327    183
# Name: Subscribers gained, dtype: int64

# %%
a.sample(5)
# Out:
# 359    209
# 356    156
# 329    154
# 343    184
# 54     101
# Name: Subscribers gained, dtype: int64

# %%
c=pd.read_csv("/content/bollywood.csv").squeeze()
c
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
#value_counts() - tells how many times a value is repeated in series
c.value_counts()
# Out:
# movie                     lead
# Andaaz                    Akshay Kumar       2
# Tanu Weds Manu: Returns   Kangana Ranaut     2
# Gabbar Is Back            Akshay Kumar       2
# Noor (film)               Sunny Leone        1
# No Smoking (2007 film)    John Abraham       1
#                                             ..
# Genius (2018 Hindi film)  Utkarsh Sharma     1
# Gayab                     Tusshar Kapoor     1
# Gauri: The Unborn         Mohan Azaad        1
# Gattu                     Naresh Sharma      1
# Global Baba               Pankaj Tripathi    1
# Name: count, Length: 1497, dtype: int64

# %%
#sort_values: gives values in ascending order used to pick smallest and largest values
b.sort_values()
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
b.sort_values(ascending=False)
#and for picking top row we use head(1)
b.sort_values(ascending=False).head(1)
#to remove match_no and 128 we can use .values() which gives a numpy array with value
b.sort_values(ascending=False).head(1).values
# Out:
# array([113])

# %%
b.sort_values().tail(1).values
# Out:
# array([113])

# %%
b
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
#sort_values(inplace = True) means change is permanent

# %%
#count() gives total no of items in series that are non missing
b.count()
# Out:
# np.int64(215)

# %%
a.sum() #sum() - gives sum of all items in series
# Out:
# np.int64(49510)

# %%
a.mean()
# Out:
# np.float64(135.64383561643837)

# %%
a.median()
# Out:
# 123.0

# %%
a.mode()
# Out:
# 0    105
# Name: Subscribers gained, dtype: int64

# %%
a.mode().values[0]
# Out:
# np.int64(105)

# %%
a.std()
# Out:
# 62.67502303725269

# %%
a.var()
# Out:
# 3928.1585127201556

# %%
b.min()
# Out:
# 0

# %%
b.max()
# Out:
# 113

# %%
#describe() - gives summary of mathematical formulas in series
b.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
#indexing - used to access an element from series
x=pd.Series([13,24,56,78,90,123,45,6,7,8])
x
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4     90
# 5    123
# 6     45
# 7      6
# 8      7
# 9      8
# dtype: int64

# %%
x[2]
# Out:
# np.int64(56)

# %%
x[3]
# Out:
# np.int64(78)

# %%
f=pd.read_csv("/content/bollywood.csv",index_col="movie")
g=f.squeeze()

# %%
g["Evening Shadows"]
# Out:
# 'Mona Ambegaonkar'

# %%
g[0]
# Out:
# /tmp/ipython-input-939630576.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   g[0]
# 'Vicky Kaushal'

# %%
#negative indexing - only works with .iloc else other considers it as label not index
g.iloc[-1]
# Out:
# 'Akshay Kumar'

# %%
b=pd.read_csv("/content/kohli_ipl.csv",index_col="match_no").squeeze()
b
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
#slicing - takes values from start+1 to n
b[4:15]
# Out:
# match_no
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# Name: runs, dtype: int64

# %%
b[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
#fancy indexing - picking required elements
b[[1,5,7,10]]
# Out:
# match_no
# 1      1
# 5      1
# 7     34
# 10     3
# Name: runs, dtype: int64

# %%
m=pd.Series({"maths":100,"english":67})
m
# Out:
# maths      100
# english     67
# dtype: int64

# %%
m[1]=92
m
# Out:
# /tmp/ipython-input-3604302886.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   m[1]=92
# maths      100
# english     92
# dtype: int64

# %%
#adding new index
m["social"]=96
m
# Out:
# maths      100
# english     92
# social      96
# dtype: int64

# %%
len(g)
# Out:
# 1500

# %%
type(g)
# Out:
# pandas.core.series.Series

# %%
min(g)
# Out:
# 'Aadar Jain'

# %%
max(g)
# Out:
# 'Zulfi Sayed'

# %%
sorted(m)
# Out:
# [92, 96, 100]

# %%
type(m)
# Out:
# pandas.core.series.Series

# %%
list(m) #converts data type
# Out:
# [100, 92, 96]

# %%
"Battalion 609" in g
# Out:
# True

# %%
b
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
#arithmetic operators
100-b
# Out:
# match_no
# 1       99
# 2       77
# 3       87
# 4       88
# 5       99
#       ...
# 211    100
# 212     80
# 213     27
# 214     75
# 215     93
# Name: runs, Length: 215, dtype: int64

# %%
b >-50
# Out:
# match_no
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
#        ...
# 211    True
# 212    True
# 213    True
# 214    True
# 215    True
# Name: runs, Length: 215, dtype: bool

# %%
b[b>=50].size
# Out:
# 50

# %%
b[b>=100].size
# Out:
# 5

# %%
b[b==0].size
# Out:
# 9

# %%
a
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a[a>200].size
# Out:
# 59

# %%
g
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
a=g.value_counts()
a[a>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
b.plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
g.value_counts().head(20)
# Out:
# lead
# Akshay Kumar          48
# Amitabh Bachchan      45
# Ajay Devgn            38
# Salman Khan           31
# Sanjay Dutt           26
# Shah Rukh Khan        22
# Emraan Hashmi         21
# Saif Ali Khan         18
# John Abraham          18
# Shahid Kapoor         17
# Sunny Deol            17
# Tusshar Kapoor        16
# Jimmy Sheirgill       16
# Irrfan Khan           14
# Manoj Bajpayee        14
# Arjun Rampal          14
# Anupam Kher           13
# Hrithik Roshan        12
# Ayushmann Khurrana    12
# Kangana Ranaut        12
# Name: count, dtype: int64

# %%
g.value_counts().head(20).plot()
# Out:
# <Axes: xlabel='lead'>

# %%
#types of graphs
#.plot() - simply we get a graph with x and y
#.plot(kind="bar")

# %%
g.value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='lead'>

# %%
g.value_counts().head(20).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>
